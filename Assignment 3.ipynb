# %%
thistuple = ("Toyota","Volkswagen","Ford","Hyundai","Honda")
print(thistuple)
print()
print("Number of Items in list are:-" , len(thistuple))
print()
print("Adding Koenigsegg to the list:-")
y = list(thistuple)
y.append("Koenigsegg")
tuple = thistuple(y)
print(thistuple)
# Out:
# ('Toyota', 'Volkswagen', 'Ford', 'Hyundai', 'Honda')
#
# Number of Items in list are:- 5
#
# Adding Koenigsegg to the list:-
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       7 y = list(thistuple)
#       8 y.append("Koenigsegg")
# ----> 9 tuple = thistuple(y)
#      10 print(thistuple)
#
# TypeError: 'tuple' object is not callable
